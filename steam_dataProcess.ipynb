# %%
# %config IPCompleter.greedy=True

# %%
##Importing all the necessary directories

import pandas as pd
import numpy as np
import re

import gensim
from gensim import models
from gensim import corpora
from gensim.parsing.preprocessing import preprocess_string
from gensim.parsing.preprocessing import remove_stopwords
from gensim.parsing.preprocessing import strip_numeric
from gensim.parsing.preprocessing import strip_punctuation
from gensim.parsing.preprocessing import strip_short
from gensim.utils import lemmatize
from gensim.utils import simple_preprocess
from gensim.models import TfidfModel
from gensim.corpora import Dictionary

import nltk
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
from nltk.tokenize import regexp_tokenize

# %%
import simplejson as json

with open('data/review_80360.json') as jsonfile:
    tmp= json.load(jsonfile)

data1 = [i for i in tmp['reviews'].values()]

steam_dict = {'recommendationid':[data1[i]['recommendationid'] for i in range(len(data1))],              
              'author_steamid':[data1[i]['author']['steamid'] for i in range(len(data1))],              
              'author_num_games_owned':[data1[i]['author']['num_games_owned'] for i in range(len(data1))],              
              'author_num_reviews':[data1[i]['author']['num_reviews'] for i in range(len(data1))],              
              'author_playtime_forever':[data1[i]['author']['playtime_forever'] for i in range(len(data1))],
              'author_playtime_last_two_weeks':[data1[i]['author']['playtime_last_two_weeks'] for i in range(len(data1))],             
              'author_last_played':[data1[i]['author']['last_played'] for i in range(len(data1))],              
              'review':[data1[i]['review'] for i in range(len(data1))],              
              'timestamp_created':[data1[i]['timestamp_created'] for i in range(len(data1))],              
              'timestamp_updated':[data1[i]['timestamp_updated'] for i in range(len(data1))],              
              'voted_up':[data1[i]['voted_up'] for i in range(len(data1))],              
              'weighted_vote_score':[data1[i]['weighted_vote_score'] for i in range(len(data1))],              
              'steam_purchase':[data1[i]['steam_purchase'] for i in range(len(data1))],              
              'received_for_free':[data1[i]['received_for_free'] for i in range(len(data1))],              
              'written_during_early_access':[data1[i]['written_during_early_access'] for i in range(len(data1))]}

df_raw1 = pd.DataFrame(steam_dict)
df_raw1['game'] = '80360'
df_raw1['success'] ='yes'

# %%
import simplejson as json

with open('data/review_252370.json') as jsonfile:
    tmp= json.load(jsonfile)

data1 = [i for i in tmp['reviews'].values()]

steam_dict = {'recommendationid':[data1[i]['recommendationid'] for i in range(len(data1))],              
              'author_steamid':[data1[i]['author']['steamid'] for i in range(len(data1))],              
              'author_num_games_owned':[data1[i]['author']['num_games_owned'] for i in range(len(data1))],              
              'author_num_reviews':[data1[i]['author']['num_reviews'] for i in range(len(data1))],              
              'author_playtime_forever':[data1[i]['author']['playtime_forever'] for i in range(len(data1))],
              'author_playtime_last_two_weeks':[data1[i]['author']['playtime_last_two_weeks'] for i in range(len(data1))],             
              'author_last_played':[data1[i]['author']['last_played'] for i in range(len(data1))],              
              'review':[data1[i]['review'] for i in range(len(data1))],              
              'timestamp_created':[data1[i]['timestamp_created'] for i in range(len(data1))],              
              'timestamp_updated':[data1[i]['timestamp_updated'] for i in range(len(data1))],              
              'voted_up':[data1[i]['voted_up'] for i in range(len(data1))],              
              'weighted_vote_score':[data1[i]['weighted_vote_score'] for i in range(len(data1))],              
              'steam_purchase':[data1[i]['steam_purchase'] for i in range(len(data1))],              
              'received_for_free':[data1[i]['received_for_free'] for i in range(len(data1))],              
              'written_during_early_access':[data1[i]['written_during_early_access'] for i in range(len(data1))]}

df_raw2 = pd.DataFrame(steam_dict)
df_raw2['game'] = '252370'
df_raw2['success'] ='yes'

# %%
import simplejson as json

with open('data/review_268540.json') as jsonfile:
    tmp= json.load(jsonfile)

data1 = [i for i in tmp['reviews'].values()]

steam_dict = {'recommendationid':[data1[i]['recommendationid'] for i in range(len(data1))],              
              'author_steamid':[data1[i]['author']['steamid'] for i in range(len(data1))],              
              'author_num_games_owned':[data1[i]['author']['num_games_owned'] for i in range(len(data1))],              
              'author_num_reviews':[data1[i]['author']['num_reviews'] for i in range(len(data1))],              
              'author_playtime_forever':[data1[i]['author']['playtime_forever'] for i in range(len(data1))],
              'author_playtime_last_two_weeks':[data1[i]['author']['playtime_last_two_weeks'] for i in range(len(data1))],             
              'author_last_played':[data1[i]['author']['last_played'] for i in range(len(data1))],              
              'review':[data1[i]['review'] for i in range(len(data1))],              
              'timestamp_created':[data1[i]['timestamp_created'] for i in range(len(data1))],              
              'timestamp_updated':[data1[i]['timestamp_updated'] for i in range(len(data1))],              
              'voted_up':[data1[i]['voted_up'] for i in range(len(data1))],              
              'weighted_vote_score':[data1[i]['weighted_vote_score'] for i in range(len(data1))],              
              'steam_purchase':[data1[i]['steam_purchase'] for i in range(len(data1))],              
              'received_for_free':[data1[i]['received_for_free'] for i in range(len(data1))],              
              'written_during_early_access':[data1[i]['written_during_early_access'] for i in range(len(data1))]}

df_raw3 = pd.DataFrame(steam_dict)
df_raw3['game'] = '268540'
df_raw3['success'] ='yes'

# %%
import simplejson as json

with open('data/review_316790.json') as jsonfile:
    tmp= json.load(jsonfile)

data1 = [i for i in tmp['reviews'].values()]

steam_dict = {'recommendationid':[data1[i]['recommendationid'] for i in range(len(data1))],              
              'author_steamid':[data1[i]['author']['steamid'] for i in range(len(data1))],              
              'author_num_games_owned':[data1[i]['author']['num_games_owned'] for i in range(len(data1))],              
              'author_num_reviews':[data1[i]['author']['num_reviews'] for i in range(len(data1))],              
              'author_playtime_forever':[data1[i]['author']['playtime_forever'] for i in range(len(data1))],
              'author_playtime_last_two_weeks':[data1[i]['author']['playtime_last_two_weeks'] for i in range(len(data1))],             
              'author_last_played':[data1[i]['author']['last_played'] for i in range(len(data1))],              
              'review':[data1[i]['review'] for i in range(len(data1))],              
              'timestamp_created':[data1[i]['timestamp_created'] for i in range(len(data1))],              
              'timestamp_updated':[data1[i]['timestamp_updated'] for i in range(len(data1))],              
              'voted_up':[data1[i]['voted_up'] for i in range(len(data1))],              
              'weighted_vote_score':[data1[i]['weighted_vote_score'] for i in range(len(data1))],              
              'steam_purchase':[data1[i]['steam_purchase'] for i in range(len(data1))],              
              'received_for_free':[data1[i]['received_for_free'] for i in range(len(data1))],              
              'written_during_early_access':[data1[i]['written_during_early_access'] for i in range(len(data1))]}

df_raw4 = pd.DataFrame(steam_dict)
df_raw4['game'] = '316790'
df_raw4['success'] ='yes'

# %%
import simplejson as json

with open('data/review_319910.json') as jsonfile:
    tmp= json.load(jsonfile)

data1 = [i for i in tmp['reviews'].values()]

steam_dict = {'recommendationid':[data1[i]['recommendationid'] for i in range(len(data1))],              
              'author_steamid':[data1[i]['author']['steamid'] for i in range(len(data1))],              
              'author_num_games_owned':[data1[i]['author']['num_games_owned'] for i in range(len(data1))],              
              'author_num_reviews':[data1[i]['author']['num_reviews'] for i in range(len(data1))],              
              'author_playtime_forever':[data1[i]['author']['playtime_forever'] for i in range(len(data1))],
              'author_playtime_last_two_weeks':[data1[i]['author']['playtime_last_two_weeks'] for i in range(len(data1))],             
              'author_last_played':[data1[i]['author']['last_played'] for i in range(len(data1))],              
              'review':[data1[i]['review'] for i in range(len(data1))],              
              'timestamp_created':[data1[i]['timestamp_created'] for i in range(len(data1))],              
              'timestamp_updated':[data1[i]['timestamp_updated'] for i in range(len(data1))],              
              'voted_up':[data1[i]['voted_up'] for i in range(len(data1))],              
              'weighted_vote_score':[data1[i]['weighted_vote_score'] for i in range(len(data1))],              
              'steam_purchase':[data1[i]['steam_purchase'] for i in range(len(data1))],              
              'received_for_free':[data1[i]['received_for_free'] for i in range(len(data1))],              
              'written_during_early_access':[data1[i]['written_during_early_access'] for i in range(len(data1))]}

df_raw5 = pd.DataFrame(steam_dict)
df_raw5['game'] = '319910'
df_raw5['success'] ='no'

# %%
import simplejson as json

with open('data/review_487120.json') as jsonfile:
    tmp= json.load(jsonfile)

data1 = [i for i in tmp['reviews'].values()]

steam_dict = {'recommendationid':[data1[i]['recommendationid'] for i in range(len(data1))],              
              'author_steamid':[data1[i]['author']['steamid'] for i in range(len(data1))],              
              'author_num_games_owned':[data1[i]['author']['num_games_owned'] for i in range(len(data1))],              
              'author_num_reviews':[data1[i]['author']['num_reviews'] for i in range(len(data1))],              
              'author_playtime_forever':[data1[i]['author']['playtime_forever'] for i in range(len(data1))],
              'author_playtime_last_two_weeks':[data1[i]['author']['playtime_last_two_weeks'] for i in range(len(data1))],             
              'author_last_played':[data1[i]['author']['last_played'] for i in range(len(data1))],              
              'review':[data1[i]['review'] for i in range(len(data1))],              
              'timestamp_created':[data1[i]['timestamp_created'] for i in range(len(data1))],              
              'timestamp_updated':[data1[i]['timestamp_updated'] for i in range(len(data1))],              
              'voted_up':[data1[i]['voted_up'] for i in range(len(data1))],              
              'weighted_vote_score':[data1[i]['weighted_vote_score'] for i in range(len(data1))],              
              'steam_purchase':[data1[i]['steam_purchase'] for i in range(len(data1))],              
              'received_for_free':[data1[i]['received_for_free'] for i in range(len(data1))],              
              'written_during_early_access':[data1[i]['written_during_early_access'] for i in range(len(data1))]}

df_raw6 = pd.DataFrame(steam_dict)
df_raw6['game'] = '487120'
df_raw6['success'] ='no'

# %%
import simplejson as json

with open('data/review_522570.json') as jsonfile:
    tmp= json.load(jsonfile)

data1 = [i for i in tmp['reviews'].values()]

steam_dict = {'recommendationid':[data1[i]['recommendationid'] for i in range(len(data1))],              
              'author_steamid':[data1[i]['author']['steamid'] for i in range(len(data1))],              
              'author_num_games_owned':[data1[i]['author']['num_games_owned'] for i in range(len(data1))],              
              'author_num_reviews':[data1[i]['author']['num_reviews'] for i in range(len(data1))],              
              'author_playtime_forever':[data1[i]['author']['playtime_forever'] for i in range(len(data1))],
              'author_playtime_last_two_weeks':[data1[i]['author']['playtime_last_two_weeks'] for i in range(len(data1))],             
              'author_last_played':[data1[i]['author']['last_played'] for i in range(len(data1))],              
              'review':[data1[i]['review'] for i in range(len(data1))],              
              'timestamp_created':[data1[i]['timestamp_created'] for i in range(len(data1))],              
              'timestamp_updated':[data1[i]['timestamp_updated'] for i in range(len(data1))],              
              'voted_up':[data1[i]['voted_up'] for i in range(len(data1))],              
              'weighted_vote_score':[data1[i]['weighted_vote_score'] for i in range(len(data1))],              
              'steam_purchase':[data1[i]['steam_purchase'] for i in range(len(data1))],              
              'received_for_free':[data1[i]['received_for_free'] for i in range(len(data1))],              
              'written_during_early_access':[data1[i]['written_during_early_access'] for i in range(len(data1))]}

df_raw7 = pd.DataFrame(steam_dict)
df_raw7['game'] = '522570'
df_raw7['success'] ='no'

# %%
import simplejson as json

with open('data/review_368990.json') as jsonfile:
    tmp= json.load(jsonfile)

data1 = [i for i in tmp['reviews'].values()]

steam_dict = {'recommendationid':[data1[i]['recommendationid'] for i in range(len(data1))],              
              'author_steamid':[data1[i]['author']['steamid'] for i in range(len(data1))],              
              'author_num_games_owned':[data1[i]['author']['num_games_owned'] for i in range(len(data1))],              
              'author_num_reviews':[data1[i]['author']['num_reviews'] for i in range(len(data1))],              
              'author_playtime_forever':[data1[i]['author']['playtime_forever'] for i in range(len(data1))],
              'author_playtime_last_two_weeks':[data1[i]['author']['playtime_last_two_weeks'] for i in range(len(data1))],             
              'author_last_played':[data1[i]['author']['last_played'] for i in range(len(data1))],              
              'review':[data1[i]['review'] for i in range(len(data1))],              
              'timestamp_created':[data1[i]['timestamp_created'] for i in range(len(data1))],              
              'timestamp_updated':[data1[i]['timestamp_updated'] for i in range(len(data1))],              
              'voted_up':[data1[i]['voted_up'] for i in range(len(data1))],              
              'weighted_vote_score':[data1[i]['weighted_vote_score'] for i in range(len(data1))],              
              'steam_purchase':[data1[i]['steam_purchase'] for i in range(len(data1))],              
              'received_for_free':[data1[i]['received_for_free'] for i in range(len(data1))],              
              'written_during_early_access':[data1[i]['written_during_early_access'] for i in range(len(data1))]}

df_raw8 = pd.DataFrame(steam_dict)
df_raw8['game'] = '368990'
df_raw8['success'] ='no'

# %%
import simplejson as json

with open('data/review_730820.json') as jsonfile:
    tmp= json.load(jsonfile)

data1 = [i for i in tmp['reviews'].values()]

steam_dict = {'recommendationid':[data1[i]['recommendationid'] for i in range(len(data1))],              
              'author_steamid':[data1[i]['author']['steamid'] for i in range(len(data1))],              
              'author_num_games_owned':[data1[i]['author']['num_games_owned'] for i in range(len(data1))],              
              'author_num_reviews':[data1[i]['author']['num_reviews'] for i in range(len(data1))],              
              'author_playtime_forever':[data1[i]['author']['playtime_forever'] for i in range(len(data1))],
              'author_playtime_last_two_weeks':[data1[i]['author']['playtime_last_two_weeks'] for i in range(len(data1))],             
              'author_last_played':[data1[i]['author']['last_played'] for i in range(len(data1))],              
              'review':[data1[i]['review'] for i in range(len(data1))],              
              'timestamp_created':[data1[i]['timestamp_created'] for i in range(len(data1))],              
              'timestamp_updated':[data1[i]['timestamp_updated'] for i in range(len(data1))],              
              'voted_up':[data1[i]['voted_up'] for i in range(len(data1))],              
              'weighted_vote_score':[data1[i]['weighted_vote_score'] for i in range(len(data1))],              
              'steam_purchase':[data1[i]['steam_purchase'] for i in range(len(data1))],              
              'received_for_free':[data1[i]['received_for_free'] for i in range(len(data1))],              
              'written_during_early_access':[data1[i]['written_during_early_access'] for i in range(len(data1))]}

df_raw9 = pd.DataFrame(steam_dict)
df_raw9['game'] = '730820'
df_raw9['success'] ='yes'

# %%
import simplejson as json

with open('data/review_1180380.json') as jsonfile:
    tmp= json.load(jsonfile)

data1 = [i for i in tmp['reviews'].values()]

steam_dict = {'recommendationid':[data1[i]['recommendationid'] for i in range(len(data1))],              
              'author_steamid':[data1[i]['author']['steamid'] for i in range(len(data1))],              
              'author_num_games_owned':[data1[i]['author']['num_games_owned'] for i in range(len(data1))],              
              'author_num_reviews':[data1[i]['author']['num_reviews'] for i in range(len(data1))],              
              'author_playtime_forever':[data1[i]['author']['playtime_forever'] for i in range(len(data1))],
              'author_playtime_last_two_weeks':[data1[i]['author']['playtime_last_two_weeks'] for i in range(len(data1))],             
              'author_last_played':[data1[i]['author']['last_played'] for i in range(len(data1))],              
              'review':[data1[i]['review'] for i in range(len(data1))],              
              'timestamp_created':[data1[i]['timestamp_created'] for i in range(len(data1))],              
              'timestamp_updated':[data1[i]['timestamp_updated'] for i in range(len(data1))],              
              'voted_up':[data1[i]['voted_up'] for i in range(len(data1))],              
              'weighted_vote_score':[data1[i]['weighted_vote_score'] for i in range(len(data1))],              
              'steam_purchase':[data1[i]['steam_purchase'] for i in range(len(data1))],              
              'received_for_free':[data1[i]['received_for_free'] for i in range(len(data1))],              
              'written_during_early_access':[data1[i]['written_during_early_access'] for i in range(len(data1))]}

df_raw10 = pd.DataFrame(steam_dict)
df_raw10['game'] = '1180380'
df_raw10['success'] ='no'

# %%
df = [df_raw1,df_raw2,df_raw3,df_raw4,df_raw5,df_raw6,df_raw7,df_raw8,df_raw9,df_raw10]

df = pd.concat(df)

# %%
df.head()
# Out:
#   recommendationid     author_steamid  author_num_games_owned  \
# 0         64396784  76561198837728086                       8
# 1         63845942  76561198047853572                     165
# 2         63741121  76561198362807778                     155
# 3         63626714  76561198121681464                     558
# 4         63302318  76561197994129822                    1610
#
#    author_num_reviews  author_playtime_forever  \
# 0                   2                      389
# 1                  97                      921
# 2                  52                      402
# 3                  63                      244
# 4                  34                      565
#
#    author_playtime_last_two_weeks  author_last_played  \
# 0                               0          1583135121
# 1                               0          1513577606
# 2                               0          1582058227
# 3                               0          1581847451
# ...

# %%
df.success
# Out:
# 0       yes
# 1       yes
# 2       yes
# 3       yes
# 4       yes
#        ...
# 1189     no
# 1190     no
# 1191     no
# 1192     no
# 1193     no
# Name: success, Length: 12195, dtype: object

# %%
# Pickle file for later use

import pickle
with open('data/df.pkl', 'wb') as pkl_file:
    pickle.dump(df, pkl_file)

# %%
with open('data/df.pkl', 'rb') as pkl_file:
    df = pickle.load(pkl_file) 
df.shape
df.head()
# Out:
#   recommendationid     author_steamid  author_num_games_owned  \
# 0         64396784  76561198837728086                       8
# 1         63845942  76561198047853572                     165
# 2         63741121  76561198362807778                     155
# 3         63626714  76561198121681464                     558
# 4         63302318  76561197994129822                    1610
#
#    author_num_reviews  author_playtime_forever  \
# 0                   2                      389
# 1                  97                      921
# 2                  52                      402
# 3                  63                      244
# 4                  34                      565
#
#    author_playtime_last_two_weeks  author_last_played  \
# 0                               0          1583135121
# 1                               0          1513577606
# 2                               0          1582058227
# 3                               0          1581847451
# ...

# %%
df.groupby('success')

# %%
#reviews data cleaning

CUSTOM_FILTER = [strip_punctuation, strip_numeric, remove_stopwords, strip_short]
# Pre-processing the data (removing punctuations, numbers, stop words and short words followed by lemmatization)
preprocess_words = []
clean_words = []
for i in range(len(df)):
    preprocess_words.append(preprocess_string(df.review.tolist()[i].lower(), CUSTOM_FILTER))

# Map POS tag to first character lemmatize()
def get_wordnet_pos(word):
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)

# Init Lemmatizer
lemmatizer = WordNetLemmatizer()
for i in range(len(df)):
    clean_words.append([lemmatizer.lemmatize(w, get_wordnet_pos(w)) for w in (preprocess_words[i])])

df['clean_words'] = clean_words

# %%
df.head()
# Out:
#   recommendationid     author_steamid  author_num_games_owned  \
# 0         64396784  76561198837728086                       8
# 1         63845942  76561198047853572                     165
# 2         63741121  76561198362807778                     155
# 3         63626714  76561198121681464                     558
# 4         63302318  76561197994129822                    1610
#
#    author_num_reviews  author_playtime_forever  \
# 0                   2                      389
# 1                  97                      921
# 2                  52                      402
# 3                  63                      244
# 4                  34                      565
#
#    author_playtime_last_two_weeks  author_last_played  \
# 0                               0          1583135121
# 1                               0          1513577606
# 2                               0          1582058227
# 3                               0          1581847451
# ...

# %%
my_dict = Dictionary(df.clean_words)
#my_dict.filter_extremes(no_below=5, no_above=0.90)

# Count Vectorization
dtm = [my_dict.doc2bow(doc) for doc in df.clean_words]

# TF-IDF Vectorization
tfidf_vectorizer = TfidfModel(dtm)
tfidf = tfidf_vectorizer[dtm]

# %%
from gensim.models import LsiModel, CoherenceModel, LdaModel


lsi_tfidf = LsiModel(corpus=tfidf, id2word=my_dict, num_topics=5)
lda_tfidf = LdaModel(corpus=tfidf, id2word=my_dict, num_topics=5)

# %%
# Get dominant topic and corresponding keywords for each article

def getKeywordsFromDominantTopic(model, corpus, texts): 
    # Init output
    topickeyword_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(model[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = model.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                topickeyword_df = topickeyword_df.append(pd.Series([topic_keywords]), ignore_index=True)
            else:
                break
    return(topickeyword_df)

# %%
df['LSI TF-IDF Keywords'] = getKeywordsFromDominantTopic(model=lsi_tfidf, corpus=tfidf, texts=df.review)
df['LDA TF-IDF Keywords'] = getKeywordsFromDominantTopic(model=lda_tfidf, corpus=tfidf, texts=df.review)

# %%
# Combine all the keywords
df['merged-keywords'] = df['LSI TF-IDF Keywords'] + ', ' + df['LDA TF-IDF Keywords']

# %%
# Get 5 most common keywords across the four groups of keywords
from collections import Counter 
for i in df.index:
    words = df.loc[i, 'merged-keywords']
    most_occur = Counter(words).most_common(3) 
    df.loc[i, 'Top 5 Freq Words'] = ','.join([word[0] for word in most_occur])

df[['review', 'Top 5 Freq Words']].head(3)
# Out:
#                                               review  \
# 0                    Things are really heating up :)
# 1  Pure awesomeness! The soundtrack is so good in...
# 2  As the other parts of the Blackwell series: I ...
#
#                                     Top 5 Freq Words
# 0  good, game, trine, great, play, fun, like, sto...
# 1  good, great, best, love, trine, adventure, fun...
# 2  good, game, trine, great, play, fun, like, sto...

# %%
df["clean_words"].head(30)
# Out:
# 0                                      [thing, heating]
# 1     [pure, awesomeness, soundtrack, good, support,...
# 2     [part, blackwell, series, love, game, interest...
# 3     [art, style, completely, change, game, bit, pi...
# 4     [haven, played, adventure, blackwell, series, ...
# 5     [take, hour, finish, decent, puzzle, challenge...
# 6     [story, get, well, well, puzzle, easy, hard, a...
# 7                            [good, point, click, game]
# 8     [underwhelming, compare, blackwell, game, stor...
# 9     [realize, year, complete, blackwell, series, m...
# 10    [deception, improves, game, tell, best, story,...
# 11    [good, game, great, series, want, blackwell, j...
# 12    [love, blackwell, series, story, interest, kep...
# 13    [obviously, played, previous, blackwell, game,...
# 14    [░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░, ░░░...
# 15    [it’s, little, year, rosa, suggest, joey, spir...
# 16    [blackwell, deception, game, blackwell, series...
# ...

# %%
from gensim.models import Word2Vec
num_features = 100
model = Word2Vec(df['clean_words'], size=num_features, window=8, min_count=2, 
    sample=1e-3, sg=1, iter=5, workers=8)
vocab = set(model.wv.index2word)
len(vocab)
# Out:
# 9574

# %%
def average_word_vectors(words, model, vocabulary, num_features):
    feature_vector = np.zeros((num_features,), dtype="float64")
    nwords = 0.
    for word in words:
        if word in vocabulary: 
            nwords = nwords + 1.
            feature_vector = np.add(feature_vector, model.wv[word])
    if nwords:
        feature_vector = np.divide(feature_vector, nwords)
    return feature_vector

# %%
features = [average_word_vectors(sent_tokens, model, vocab, 
    num_features) for sent_tokens in df['clean_words']]
avg_features = np.array(features)

# %%
print('Word2Vec model: \n features shape:', avg_features.shape)
# Out:
# Word2Vec model:
#  features shape: (12195, 100)

# %%
def get_sim(word1, sent):
    sent_sim = 0
    nwords = 0
    for word2 in sent:
        if(word2 in vocab) and (model.wv.similarity(w1 = word1, w2 = word2) >0.5 or model.wv.similarity(w1 = word1, w2 = word2) < -0.5):
            sent_sim = sent_sim + model.wv.similarity(w1 = word1, w2 = word2)
            nwords = nwords + 1
        if nwords == 0:
            return 0
        else:
            return round(sent_sim/nwords,3)

# Function to extract features from text data using the custom similarity function (get_sim)
# The features range between (-1 to 1)
def feature_extraction(df):
    df = df.reset_index()
    for i in range(len(df)):
        df.loc[i,"good_story_interesting_sim"] = get_sim("story",df.loc[i,"clean_words"])
        df.loc[i,"fun_love_awesome_sim"] = get_sim("good",df.loc[i,"clean_words"])
        df.loc[i,"great_adventure_sim"] = get_sim("adventure",df.loc[i,"clean_words"])
        df.loc[i,"bad_awful_boring_sim"] = get_sim("bad",df.loc[i,"clean_words"])
    return df

# %%
x2 = feature_extraction(df['clean_words'])

# %%
print(x2.head(30))
# Out:
#     index                                        clean_words  \
# 0       0                                   [thing, heating]
# 1       1  [pure, awesomeness, soundtrack, good, support,...
# 2       2  [part, blackwell, series, love, game, interest...
# 3       3  [art, style, completely, change, game, bit, pi...
# 4       4  [haven, played, adventure, blackwell, series, ...
# 5       5  [take, hour, finish, decent, puzzle, challenge...
# 6       6  [story, get, well, well, puzzle, easy, hard, a...
# 7       7                         [good, point, click, game]
# 8       8  [underwhelming, compare, blackwell, game, stor...
# 9       9  [realize, year, complete, blackwell, series, m...
# 10     10  [deception, improves, game, tell, best, story,...
# 11     11  [good, game, great, series, want, blackwell, j...
# 12     12  [love, blackwell, series, story, interest, kep...
# 13     13  [obviously, played, previous, blackwell, game,...
# ...
